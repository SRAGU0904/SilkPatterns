# %%
import os
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urljoin

# %%
def safe_get(url, retries=3, timeout=10, delay=2):
    for attempt in range(retries):
        try:
            response = requests.get(url, timeout=timeout)
            return response
        except requests.exceptions.RequestException as e:
            print(f"Try {attempt+1}/{retries} Failure：{e}")
            time.sleep(delay)
    print(f"Finall failure: {url}")
    return None

# %%
def crawl_single_detail_page(base_url, detail_url, save_folder):
    try:
        response = requests.get(detail_url, timeout=10)
        response.encoding = 'utf-8'
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract the item's name
        name_tag = soup.find('div', class_='detail_h')
        if not name_tag:
            raise ValueError("name is invalid!")
        name = name_tag.text.strip()
        safe_name = "".join(c for c in name if c.isalnum() or c in "_-（）()").strip()

        # Extract images and description text
        detail_text_div = soup.find('div', class_='detail_text')
        if not detail_text_div:
            raise ValueError("description is invalid!")

        imgs = detail_text_div.find_all('img')
        description = detail_text_div.get_text(separator='\n', strip=True)

        # Download and save all images
        for i, img in enumerate(imgs):
            img_url = urljoin(base_url, img['src'])
            ext = os.path.splitext(img_url)[-1] or '.jpg'
            if len(imgs) == 1:
                img_filename = f"{safe_name}{ext}"
            else:
                img_filename = f"{safe_name}_{i+1}{ext}"
            img_path = os.path.join(save_folder, img_filename)

            img_data = requests.get(img_url, timeout=10).content
            with open(img_path, 'wb') as f:
                f.write(img_data)

        print(f"finished: {name}")
        return {'url': detail_url, 'name': name, 'description': description}

    except Exception as e:
        print(f"Error: {detail_url}, Reason: {e}")
        # Even on failure, return the URL with None for name and description for later review
        return {'url': detail_url, 'name': None, 'description': None}

# %%
def crawl_all_pages_and_details(base_url, first_page, save_folder='data_museum/image'):
    """
    Crawl through all pagination pages, extract detail page links on each page,
    and immediately crawl content from each detail page.
    
    :param base_url: The base URL of the website
    :param first_page: The initial pagination path to start crawling
    :param save_folder: Folder to save downloaded images
    :return: A DataFrame containing item name and description
    """
    os.makedirs(save_folder, exist_ok=True)
    current_url = urljoin(base_url, first_page)
    data = []

    while True:
        print(f"The current result page being processed is: {current_url}")
        response = requests.get(current_url)
        response.encoding = 'utf-8'
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract detail page links from <p class="p"> and crawl them immediately
        for p_tag in soup.find_all('p', class_='p'):
            a_tag = p_tag.find('a', href=True)
            if a_tag and '/zggd/info_21.aspx?itemid=' in a_tag['href']:
                full_url = urljoin(base_url, a_tag['href'])
                item_data = crawl_single_detail_page(base_url, full_url, save_folder)
                if item_data:
                    data.append(item_data)

        # Handle pagination: find the "next page" link
        next_page_tag = soup.find('a', class_='a_next')
        if not next_page_tag or next_page_tag['href'] == 'javascript:void(0);':
            print("Reached the last page.")
            break

        next_href = next_page_tag['href']
        current_url = urljoin(base_url, next_href)

        time.sleep(2)  # Prevent sending requests too frequently

    return pd.DataFrame(data)

# %%
base_url = 'https://www.chinasilkmuseum.com/zggd/'
SuiTang_url = ['list_21.aspx?lcid=&jishu=&era=%u968B%u5510&title=&storage=','SuiTang']
Song_url = ['list_21.aspx?lcid=&jishu=&era=%u5B8B%u4EE3&title=&storage=','Song']
Liao_url = ['list_21.aspx?lcid=&jishu=&era=%u8FBD%u4EE3&title=&storage=','Liao']
Yuan_url = ['list_21.aspx?lcid=&jishu=&era=%u5143%u4EE3&title=&storage=','Yuan']
Ming_url = ['list_21.aspx?lcid=&jishu=&era=%u660E%u4EE3&title=&storage=','Ming']
Qing_url = ['list_21.aspx?lcid=&jishu=&era=%u6E05%u4EE3&title=&storage=','Qing']
first_pages = [SuiTang_url,Song_url,Liao_url,Yuan_url,Ming_url,Qing_url]

# %%
all_data_df = pd.DataFrame(columns=['url', 'name', 'description', 'dynasty'])

# Iterate through each entry page (dynasty section)
for first_page in first_pages:
    print(f"\nBegin to process: {first_page[1]}")
    page_df = crawl_all_pages_and_details(base_url, first_page[0])
    page_df['dynasty'] = first_page[1]
    all_data_df = pd.concat([all_data_df, page_df], ignore_index=True)

# Save all collected data to CSV
all_data_df.to_csv('data_museum/metadata_silk_museum.csv', index=False, encoding='utf-8-sig')
# Out:
# Begin to process：SuiTang
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?lcid=&jishu=&era=%u968B%u5510&title=&storage=
# finished: 唐绿地团窠联珠对山羊纹锦
# finished: 唐代团窠联珠对狮纹锦
# finished: 唐代团窠联珠对孔雀纹锦
# finished: 唐黄地团窠联珠对马纹锦
# finished: 唐蓝绿色地团窠联珠对格力芬纹锦
# finished: 唐团窠对羊纹锦
# finished: 唐代联珠兽纹锦
# finished: 唐代大窠宝花纹绫
# finished: 唐花鸟纹锦
# finished: 唐对鸟纹锦
# finished: 唐联珠对孔雀纹锦
# finished: 唐墨绘腰带
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u968B%u5510&page=2
# finished: 唐红综色纬锦
# finished: 唐彩绘小花罗
# finished: 唐黄地对鸟纹锦边饰
# finished: 唐大红绢覆面
# finished: 唐团窠对鸟衔授带锦
# finished: 唐红地对鸟纹锦
# finished: 唐宝花纹锦
# finished: 唐小菱格纹绫
# finished: 唐黄地团窠尖瓣对鸟纹锦
# finished: 唐红地花瓣联珠对鹿纹锦
# finished: 唐红地对雕纹纬锦
# finished: 唐绿色菱格小花纹绫
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u968B%u5510&page=3
# finished: 唐综红地带式联珠纹锦
# finished: 唐团窠纹锦
# finished: 唐代联珠对鸟纹锦
# finished: 唐团窠纹锦
# finished: 唐代团窠对鹿纹锦袖头
# finished: 唐代对鹿纹锦
# finished: 唐代团窠对鹿纹锦
# finished: 唐联珠纹锦
# finished: 条形花卉纹锦衣残片
# finished: 唐红地团窠对兽纹锦
# finished: 红地团窠对牛纹锦
# finished: 黄地宝花纹锦
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u968B%u5510&page=4
# finished: 红地兽纹锦
# finished: 红地对鸟纹锦
# finished: 红地兽纹锦
# finished: 唐红色联珠对兽纹暗花绮
# finished: 红地团窠对鸟纹锦
# finished: 唐锦片
# finished: 褐色花卉纹锦
# finished: 白描熟褐色绢
# finished: 黄色方格纹绮
# finished: 红地大窠对格力芬锦
# finished: 黄地联珠纹锦
# finished: 黄色绢织物
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u968B%u5510&page=5
# finished: 方格纹锦
# finished: 唐褐色绢
# finished: 黄地对鸟纹锦
# finished: 花卉纹锦
# finished: 黄地宝花纹锦
# finished: 黄地团窠纹锦
# finished: 联珠对龙纹绫
# finished: 团窠对鸟纹锦
# finished: 宝花纹锦
# finished: 黄地团窠花鸟纹锦
# finished: 黄地联珠纹锦
# finished: 黄地团窠花鸟纹锦
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u968B%u5510&page=6
# finished: 黄地圈绒绣球路纹片
# finished: 唐黄色联珠对狮纹锦残片
# finished: 联珠纹锦
# finished: 唐黄色宝花对鹿纹锦残片
# finished: 红地小样花锦
# finished: 红地联珠五彩鸟纹锦
# finished: 蓝绢片
# finished: 唐黄地锯齿窠对鸟纹锦
# finished: 小花夹缬绢
# finished: 团窠联珠对羊纹锦
# finished: 团窠联珠对狮纹锦
# finished: 团窠联珠对牛纹锦
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u968B%u5510&page=7
# finished: 团窠联珠对孔雀纹锦
# finished: 联珠小团花纹锦
# finished: 联珠团花纹锦
# finished: 联珠拱券树纹锦
# finished: 联珠大鹿纹锦
# finished: 立鸟纹锦
# finished: 立凤团花纹绣
# finished: 锦缘绢制品
# finished: 红地独窠蝶绕莲花绫
# finished: 红地瓣窠对鸟纹锦
# finished: 朵花纹蓝地蜡缬绢
# finished: 对波童子纹锦
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u968B%u5510&page=8
# finished: 大张纬锦残角
# finished: 宝花纹锦
# finished: 宝花纹锦
# finished: 联珠对鸟纹锦
# finished: 宝花纹锦
# finished: 花鸟纹刺绣夹缬罗
# 已经到达最后一页。
#
# Begin to process：Song
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?lcid=&jishu=&era=%u5B8B%u4EE3&title=&storage=
# finished: 花卉纹绫
# finished: 折枝花绫
# finished: 罗带
# finished: 褐色缠枝山茶花罗
# finished: 折枝暗花夹缬罗
# finished: 黄色缠枝山茶花罗
# finished: 印金罗
# finished: 酱色松竹梅暗花罗
# finished: 酱色絁
# finished: 香色素罗
# finished: 绿色折枝花卉印花罗
# finished: 香色素绢
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u5B8B%u4EE3&page=2
# finished: 黄色折枝梅花绮
# finished: 绿色素罗
# finished: 黄色穿枝花鸟纹绫
# finished: 黄褐色如意山茶暗花罗
# finished: 黄色缠枝山茶花罗
# finished: 黄色杂宝纹绫
# finished: 黄色缠枝牡丹山茶花绫
# finished: 夹缬飞燕纹柿蒂花罗
# finished: 黄褐色缠枝牡丹纹罗
# finished: 黄色牡丹纹绫
# finished: 棕色素罗
# finished: 花卉斜纹罗
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u5B8B%u4EE3&page=3
# finished: 褐色绢
# finished: 黄色素纱
# finished: 棕色绉纱
# finished: 褐色纱
# finished: 折枝花卉璎珞花绫
# finished: 褐色纱
# finished: 蓝地对鹿纹锦
# finished: 蓝地小团花纹锦
# finished: 星地折枝花卉纹绫裙
# finished: 褐色罗裙
# finished: 罗地小脚鞋
# finished: 高筒绢袜
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u5B8B%u4EE3&page=4
# finished: 星地折枝花绫裙
# finished: 绢袜
# finished: 折枝朵花纹纱罗裙
# finished: 罗衫
# finished: 折枝朵花纹纱衫
# finished: 折枝花罗衫
# finished: 小花菱纹罗单衣片
# finished: 四合云纹缎交领袍
# finished: 罗鞋
# finished: 折枝花鸟纹亮地纱裙
# finished: 杂宝花罗裙裤
# finished: 素罗大袖袍
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u5B8B%u4EE3&page=5
# finished: 素罗背子
# 已经到达最后一页。
#
# Begin to process：Liao
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?lcid=&jishu=&era=%u8FBD%u4EE3&title=&storage=
# finished: 大雁纹绫
# finished: 泥金盘球纹绫
# finished: 朵云纹绫
# finished: 菱格小花绮
# finished: 缠枝团花绫短袖袍残片
# finished: 散点回纹绫
# finished: 浅褐色方点纹绫
# finished: 深褐色方点纹绫
# finished: 四鹰团花绫地泥金蔓草
# finished: 盘凤纹绫
# finished: 絁袍残片
# finished: 黄色宝花绫
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u8FBD%u4EE3&page=2
# finished: 黄色菱纹格小花绮
# finished: 褐色盘球纹绫
# finished: 黄色菱纹格绫
# finished: 团窠花树下对凤鹿纹花绫
# finished: 深褐色菱点花罗
# finished: 褐色团窠对凤织金锦
# finished: 褐色云纹动物锦
# finished: 辽黄地菱格花卉奔兽纹锦
# finished: 辽黄色花卉纹绫
# finished: 辽黄地小团对鸽纹锦
# finished: 辽联珠灵芝云纹锦
# finished: 辽黄地大雁宝花纹锦
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u8FBD%u4EE3&page=3
# finished: 辽黄地四雁宝花纹锦
# finished: 辽黄地雁纹锦
# finished: 辽黄地团凤纹绫
# finished: 辽黄地鹭鸶绕花纹锦
# finished: 辽黄色纬锦残片
# finished: 辽褐色八瓣团花纹绫
# finished: 辽黄地鹭鸶宝花纹锦
# finished: 辽黄地团窠纹锦
# finished: 辽黄地团凤纹绫
# finished: 辽黄地团窠宝花纹锦
# finished: 辽黄色纬锦残片
# finished: 辽褐色八瓣团花纹绫
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u8FBD%u4EE3&page=4
# finished: 辽大雁纹锦
# finished: 辽黄地团窠纹锦
# finished: 辽水波地团花纹锦
# finished: 辽团窠四雁衔花枝纹锦
# finished: 辽蓝色团雁纹锦
# finished: 辽簇四对凤纹锦残片
# finished: 黄地瓣窠人物妆花绫
# finished: 黄色菱格地四瓣小花绮
# finished: 紫色菱格卷云团花绮
# finished: 包裹绢
# finished: 紫色菱格小花绮
# finished: 花卉纹锦
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u8FBD%u4EE3&page=5
# finished: 紫色素罗
# finished: 大雁纹绫
# Error: https://www.chinasilkmuseum.com/zggd/info_21.aspx?itemid=2420, Reason: HTTPSConnectionPool(host='www.chinasilkmuseum.com', port=443): Max retries exceeded with url: /zggd/info_21.aspx?itemid=2420 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000023EE2232110>, 'Connection to www.chinasilkmuseum.com timed out. (connect timeout=10)'))
# finished: 泥金盘球纹绫
# finished: 菱格小花绮
# finished: 散点回纹绫
# finished: 缠枝团花绫短袖袍残片
# finished: 浅褐色方点纹绫
# finished: 四鹰团花绫地泥金蔓草
# finished: 深褐色方点纹绫
# finished: 盘凤纹绫
# finished: 絁袍残片
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u8FBD%u4EE3&page=6
# finished: 云南方胜四雁纹绫
# finished: 黄色十字花纹绫
# finished: 黄色丝纱
# finished: 褐色菱点罗
# finished: 褐色小菱纹罗
# finished: 花卉纹绫
# finished: 鹧鸪海石榴纹妆花绫
# finished: 罗地压金彩绣山林双鹿
# finished: 盘金绣团窠卷草对雁罗
# finished: 花卉纹锦裙
# 已经到达最后一页。
#
# Begin to process：Yuan
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?lcid=&jishu=&era=%u5143%u4EE3&title=&storage=
# finished: 罗带
# finished: 绮地印金石榴纹襟缘
# finished: 元代刺绣枕顶
# finished: 肩襕纹样纳石失
# finished: 双头鸟纳石失
# finished: 瓣窠纳石失
# finished: 元黄色素绢
# finished: 元铠甲琐纹织金锦
# finished: 元褐色地卷草纹锦
# finished: 元代墨绿回纹地雁衔花枝纹绫
# finished: 元缂丝缠枝牡丹
# finished: 元团窠对鸟纹彩锦
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u5143%u4EE3&page=2
# finished: 织金奔鹿
# finished: 绢片
# finished: 缠枝花卉缎残片
# finished: 锦片
# finished: 绉纱结
# finished: 红色泰罗
# finished: 罗带
# finished: 褐色织金绢
# finished: 红绢片
# finished: 黄绢残片
# finished: 云凤纹绫
# finished: 菱格龙纹绮
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u5143%u4EE3&page=3
# finished: 万字菱格杂宝小花纹绮
# finished: 罗地印金杂花襟缘
# finished: 绮地印金石榴纹襟缘
# finished: 双胜纹妆花纱襟缘
# finished: 元牡丹花绫残片
# finished: 元牡丹花绫残片
# finished: 元牡丹花绫残片
# finished: 元纳石失织金锦袍衣襟
# finished: 滴珠兔纹织金锦
# finished: 球路纹朵花绢
# finished: 缂丝玉兔云肩残片
# finished: 缂丝天鹿云肩残片
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u5143%u4EE3&page=4
# finished: 凤穿牡丹纹织金锦
# finished: 对鸟纹彩锦
# finished: 龟背地团花锦
# finished: 印金罗长袖衫 印金罗短袖衫
# finished: 蒙元暗花绫腰线袍
# finished: 蒙元六出地格力芬花绫裤
# finished: 元云头龙凤杂宝纹暗花绫半臂袍
# finished: 蒙元纳石失靴套
# finished: 元笠帽
# finished: 元绢帽
# finished: 元姑姑冠花绮抹额
# finished: 元龟背地团花锦马甲
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u5143%u4EE3&page=5
# finished: 元纳石失织金锦桃形窠姑姑冠冠披
# finished: 黄地花卉纹绫印金卧兽纹对襟上衣
# finished: 织金绫大袖袍
# finished: 绿色花卉纹绫印金方搭纹半臂
# finished: 花卉纹罗袍
# finished: 锦缘绢袍
# Error: https://www.chinasilkmuseum.com/zggd/info_21.aspx?itemid=1850, Reason: HTTPSConnectionPool(host='www.chinasilkmuseum.com', port=443): Max retries exceeded with url: /zggd/info_21.aspx?itemid=1850 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000023EE060F550>, 'Connection to www.chinasilkmuseum.com timed out. (connect timeout=10)'))
# finished: 暗花绫腰线袍
# finished: 印金罗长袖衫
# finished: 印金罗短袖衫
# finished: 纳石失靴套&六出地格力芬绫裤
# finished: 菱地飞鸟纹绫海青衣
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u5143%u4EE3&page=6
# finished: 辫线袍
# 已经到达最后一页。
#
# Begin to process：Ming
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?lcid=&jishu=&era=%u660E%u4EE3&title=&storage=
# finished: 明万字曲水纹缎头巾
# finished: 明璎珞纹妆花缎
# finished: 明黄地缠枝云竹纹缎
# finished: 明蓝地折枝花卉纹缎
# finished: 明黄色四合如意云杂宝纹缎
# finished: 黄地童子妇人纹花绫
# finished: 明熟褐色缠枝花卉纹缎
# finished: 明缠枝花卉纹绫
# finished: 奔兔纹缎
# finished: 絁片
# finished: 绢裙残片
# finished: 黄色絁
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u660E%u4EE3&page=2
# finished: 花卉纹妆花罗残片
# finished: 素缎面背袋
# finished: 素缎褥
# finished: 水波杂宝飞雁纹缎残片
# finished: 龟背万字纹花绢长袖夹衣残片
# finished: 云纹缎裙残片
# finished: 缠枝牡丹纹缎裙残片
# finished: 万字纹缎方巾
# finished: 杂宝缠枝花卉纹缎袍残片
# finished: 绿色花卉双鱼纹缎经书
# finished: 红色花卉纹闪缎经皮子
# finished: 木红色花卉纹缎经皮子
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u660E%u4EE3&page=3
# finished: 绿色缠枝花纹罗经皮子
# finished: 绿色曲水花卉纹织金缎经皮子
# finished: 绿色杂宝云纹织金缎经皮子
# finished: 蓝色杂宝花罗经皮子
# finished: 蓝色杂宝云鹊纹花罗经皮子
# finished: 丈青色杂宝花纹罗经皮子
# finished: 深蓝地杂宝纹花罗经皮子
# finished: 明黄四合云纹罗经皮子
# finished: 彩条纹绸经皮子
# finished: 明黄折枝花卉云龙妆花缎经皮子
# finished: 绿色缠枝莲织金锦经皮子
# finished: 蓝色缠枝莲龙纹织金缎经皮子
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u660E%u4EE3&page=4
# finished: 绿色万字花卉纹织锦缎经皮子
# finished: 蓝云缎地龙纹料
# finished: 时灰色杂宝云纹花纱经皮子
# Error: https://www.chinasilkmuseum.com/zggd/info_21.aspx?itemid=2536, Reason: HTTPSConnectionPool(host='www.chinasilkmuseum.com', port=443): Max retries exceeded with url: /uploadfiles/downloadimg/20171229114331171.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000023EE1133D90>, 'Connection to www.chinasilkmuseum.com timed out. (connect timeout=10)'))
# finished: 黄色绢
# finished: 褐色回纹绫残片
# finished: 深褐素面缎手帕
# finished: 弘治五年缎地文书
# finished: 缠枝牡丹暗花缎棺垫
# finished: 卍字如意云纹绸
# finished: 四合如意纹绫
# finished: 曲水牡丹花纹绫
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u660E%u4EE3&page=5
# finished: 素缎
# finished: 蓝地缠枝八吉祥织金缎
# finished: 四合如意纹绫
# finished: 佛经封面
# finished: 四合如意云纹实地纱窄袖袍
# finished: 万字花卉纹绸裙
# finished: 曲水如意云纹罗裙
# finished: 明褐绢袍
# finished: 浅褐云纹纱内衣残片
# finished: 素面褐罗金丝刺绣裙
# finished: 绢裤残片
# finished: 四合云纹绮寿衣
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u660E%u4EE3&page=6
# finished: 明代曲水如意云纹暗花缎曳撒袍
# finished: 绢袜+裹脚纱
# finished: 绢面绵袜
# finished: 辑线绣如意纹缎鞋
# finished: 刺绣牡丹花纹缎鞋
# finished: 钉金绣牡丹花纹缎鞋
# finished: 素纱裙
# finished: 卍字田格纹绮长袖夹衣
# finished: 绣花卉纹缘素罗短袖夹衣
# finished: 黄色素罗绣花方补交领袍
# finished: 黄色缠枝花卉暗花缎绵裤
# finished: 黄色素绢甲子
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u660E%u4EE3&page=7
# finished: 卍字如意云纹绸袍
# finished: 褐色曲水云纹交领袍
# finished: 四合如意云纹实地纱窄袖袍
# finished: 浅褐纱裙
# finished: 浅褐缠枝牡丹纹缎上衣
# finished: 素面波纹夹衣
# finished: 绢裙
# finished: 曲水纹绸长衫
# finished: 黄色绢衫
# finished: 曲水牡丹纹绫长裤
# finished: 曲水如意云绸夹裙
# finished: 绢衫
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u660E%u4EE3&page=8
# finished: 染缬缎帽
# finished: 云纹缎鞋
# finished: 缠枝花卉纹缎袜套
# finished: 素绢裙
# finished: 折枝花卉纹绫绵衣
# finished: 黄绮卍字折枝花卉女裙
# finished: 平安如意暗花缎寿衣
# finished: 浅褐平纹绢无领大襟女单衣
# finished: 黄绮折枝花卉女单衣
# finished: 绢短袖衫&绮长袖衫&绢裙
# 已经到达最后一页。
#
# Begin to process：Qing
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?lcid=&jishu=&era=%u6E05%u4EE3&title=&storage=
# finished: 晚清黑缎地平绣唐诗暖耳
# finished: 纳纱绣缀大雁方补
# finished: 黑缎绦带衣领镶边
# finished: 蓝缎彩绣花蝶纹袖头
# finished: 宝蓝缎盘金绣龙凤寿字纹袖头
# finished: 盘金绣锦鸡方补
# finished: 盘金绣鹭鸶方补
# finished: 彩绣鹭鸶方补
# finished: 丝绒残衣片
# finished: 蓝色织锦
# finished: 盘金绣云雁方补
# finished: 织锦鸂鶒方补（前补）
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=2
# finished: 盘金绣狮子方补
# finished: 盘金绣豹方补
# finished: 彩绣虎方补
# finished: 补子缀鸟
# finished: 刺绣彩云海水空补（前）
# finished: 彩绣狮子方补（前）
# finished: 彩绣狮子方补（后）
# finished: 盘金绣仙鹤戏补
# finished: 盘金绣正龙戏补
# finished: 大红缎镶机头桌围
# finished: 大红万蝠绸圈金彩绣大窠婴戏图桌围
# finished: 宝蓝缎打籽绣梅花水仙袖头
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=3
# finished: 织锦练雀方补（前）
# finished: 褐色缎棺垫
# finished: 缂丝云雁方补
# finished: 串枝莲花纹缎被面
# finished: 大红绸地彩绣五福万寿纹被
# finished: 织锦锦鸡前补
# finished: 驼色折枝牡丹花缎
# finished: 深蓝色几何纹小花绸匹料
# finished: 折枝花卉纹纱
# finished: 曲水折枝花卉绸
# finished: 黄缎地富贵多子纹棺垫
# finished: 黄黑间横条花卉绸棺垫片
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=4
# finished: 黄色花卉绸棺垫
# finished: 黄色蝴蝶牡丹花缎棺垫
# finished: 褐色菊花飞蝶缎棺垫
# finished: 黄色花卉绸棺垫
# finished: 黄色花卉绸棺垫
# finished: 五福捧寿绒织物
# finished: 黄色花卉织锦袖头
# finished: 黄色花卉织锦袖头
# finished: 博古纹织锦袖头
# finished: 博古纹织锦袖头
# finished: 花卉织锦袖头
# finished: 黑缎钉线绣花蝶袖头
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=5
# finished: 白缎彩绣梅兰竹菊袖头
# finished: 白缎彩绣花鸟袖头
# finished: 白缎彩绣团鹤花蝶袖头
# finished: 白绫彩绘人物地景袖头
# finished: 白绸印皮球花袖头
# finished: 白绸印人物地景袖头
# finished: 白缎钉线绣花卉袖头
# finished: 宝蓝圈金贴绣太平富贵袖头
# finished: 蓝缎盘金绣双狮金锭案围
# finished: 石青色织锦孔雀方补
# finished: 石青缎地刺绣狮子方补
# finished: 匹料腰封
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=6
# finished: 清盘金绣云龙纹绣片
# finished: 清红地彩绣人物风景纹挽袖
# finished: 清蓝地彩绣蝶恋花纹挽袖
# finished: 清深蓝地彩绣蝶恋花纹挽袖
# finished: 晚清酱色缎地团花纹绒
# finished: 清代浅棕色狮龙纹丝绒椅披
# finished: 清代红色牡丹蝴蝶纹暗花绸
# finished: 清白地八达晕锦
# finished: 清蓝地凤穿牡丹纹锦
# finished: 清黄地樗蒲纹妆花缎
# finished: 清绿地万寿蝠纹妆花缎
# finished: 清深蓝色地杂宝纹织金缎
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=7
# finished: 清玄色地团花蝴蝶纹袍料
# finished: 清绫地彩绣红藤罗花纹衣料
# finished: 清蓝绫地加绣仿真牡丹团金寿字满钩金小坎肩衣料
# finished: 清石青缎地压金彩绣红芝仙竹团金寿纹衣料
# finished: 清蓝缎地压金彩绣红芝水仙团金寿衣料
# finished: 清石青缎地彩绣藤萝花纹衣料
# finished: 清石青缎地彩绣折枝桂花纹衣料
# finished: 清浅湖绿色团寿纹缂金
# finished: 清纳锦绣白鹇纹圆补
# finished: 清黑缎地压金彩绣豹纹补
# finished: 清黑缎地彩绣练雀纹补
# finished: 清彩绣白鹇纹补
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=8
# finished: 清盘金绣鹌鹑纹补
# finished: 清彩绣八宝白鹇纹补
# finished: 清盘金绣鸂鶒纹补
# finished: 清白鹇纹补
# finished: 清纳纱绣练雀纹补
# finished: 清缂丝鹭鸶纹补
# finished: 清彩绣寿桃灵芝白鹇纹补
# finished: 清盘金彩绣云纹补
# finished: 清压金彩绣锦鸡纹补
# finished: 清盘金绣锦鸡纹前补
# finished: 清黑缎地压金彩绣鹭鸶纹后补
# finished: 方格花卉杂宝闪缎
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=9
# finished: 琐地瓣窠八吉祥锦
# finished: 深蓝濮院绸
# finished: 龟背卍字锦
# finished: 云凤花卉锦
# finished: 黑白万字纹双层锦
# finished: 浅蓝濮院绸
# finished: 唐卡
# finished: 红缎地平金绣二龙戏珠片
# finished: 翠蓝地银卍字缎
# finished: 宝蓝地银卍字缎
# finished: 绿地小团龙杂宝织金缎
# finished: 绿地小团龙杂宝织金缎
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=10
# finished: 明黄地缠枝莲织银缎
# finished: 明黄地缠枝莲织银缎
# finished: 明黄地五彩云龙妆花缎
# finished: 蓝地缠枝莲织金缎
# finished: 红地五彩妆花蟒缎
# finished: 黄地五彩霞锦
# finished: 明黄地缠枝莲织金缎
# finished: 紫地缠枝缎
# finished: 黑地闪花缎
# finished: 满地五彩锦
# finished: 明黄地缎
# finished: 红地绣团凤灵芝花草缎
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=11
# finished: 明黄地缎
# finished: 红地绣团凤灵芝花草缎
# finished: 红地绣梅花缎
# finished: 红地绣团凤灵芝花草缎
# finished: 绿地缂丝团寿字料
# finished: 宝蓝地蝙蝠缎
# finished: 黄地五彩寸蟒缎
# Error: https://www.chinasilkmuseum.com/zggd/info_21.aspx?itemid=2592, Reason: HTTPSConnectionPool(host='www.chinasilkmuseum.com', port=443): Max retries exceeded with url: /uploadfiles/downloadimg/20171229114727750.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000023EE201B650>, 'Connection to www.chinasilkmuseum.com timed out. (connect timeout=10)'))
# finished: 明黄地折枝牡丹缎零料
# finished: 明黄地万福万寿缎
# finished: 明黄地团龙绸
# finished: 藕色直径纱
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=12
# finished: 明黄地芝麻纱
# finished: 明黄地直径纱
# finished: 黄呢
# finished: 浅蓝地折枝牡丹海东纱
# finished: 杏黄丝绒
# finished: 黄地印花呢
# finished: 蓝地团龙缎
# finished: 蓝缎地盘金彩绣云蝠寿字纹零料
# finished: 团鹤绣
# finished: 花卉纹绣
# finished: 品蓝亮地纱
# finished: 万字织银缎
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=13
# finished: 大红缎地团凤盘金绣
# finished: 蓝色团龙纹芝麻纱行袍
# finished: 蓝色蝠寿纹绸长衫
# finished: 紫色花卉纹绸饰品
# finished: 大红皮球花绨地女衫
# finished: 黄色麻布衫
# finished: 白色麻布纱地背心
# finished: 黄色麻布裤
# finished: 蓝色麻布裤
# finished: 白麻布大襟女衫
# finished: 绿色龟背杂宝纹绸脚套
# finished: 蓝色折枝花鸟纹皮球花绸脚套
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=14
# finished: 灰色蝴蝶兰花皮球花纹绸裤套
# finished: 月白色镶花边女绢衫
# finished: 灰色花卉纹缎马褂
# finished: 紫色芙蓉花缎女衫
# finished: 浅褐色万事如意纹绸夹棉长衫
# finished: 石青色芙蓉花绸皮毛坎肩
# finished: 宝蓝色云鹤纹绸皮袄
# finished: 浅灰色花卉纹绸长衫
# Error: https://www.chinasilkmuseum.com/zggd/info_21.aspx?itemid=2024, Reason: HTTPSConnectionPool(host='www.chinasilkmuseum.com', port=443): Max retries exceeded with url: /uploadfiles/downloadimg/20171229110833802.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000023EE0931110>, 'Connection to www.chinasilkmuseum.com timed out. (connect timeout=10)'))
# finished: 浅蓝布镶花边女衣
# finished: 蓝色折枝牡丹花绸袍
# finished: 绛紫色葡萄纹暗花缎袍
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=15
# finished: 蓝色团龙纹江绸袍
# finished: 蓝色皮球花纹绸女衣
# finished: 石青缎对襟女衫
# finished: 褐色团花鹤鹿同春纹袍
# finished: 湖蓝色花卉拐子纹绸长衫
# finished: 湖蓝葡萄纹罗女衣
# finished: 豆沙色花卉纹绸小马甲
# finished: 黄色团龙纹江绸便袍
# finished: 蓝色牡丹花暗花缎马甲
# finished: 丝绒女衣
# finished: 石青色缎地女褂
# finished: 黑缎地镶绣梅花纹袖头女褂
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=16
# finished: 蓝藕闪色小菱纹绸女夹袄
# finished: 藕色纺绸女衣
# finished: 石青色团龙纹宽袖褂
# finished: 石青色团龙纹绸褂
# finished: 大红绣花旗服
# finished: 紫色花卉纹绵袄
# finished: 玫红山茶花纹缎女裤
# finished: 雪青暗八仙纹绸马甲
# finished: 石青色团龙直径纱男袍
# finished: 紫色女布衫
# Error: https://www.chinasilkmuseum.com/zggd/info_21.aspx?itemid=1992, Reason: HTTPSConnectionPool(host='www.chinasilkmuseum.com', port=443): Max retries exceeded with url: /zggd/info_21.aspx?itemid=1992 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000023EE0DF6410>, 'Connection to www.chinasilkmuseum.com timed out. (connect timeout=10)'))
# finished: 石青缎男长衫
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=17
# finished: 大红皮球花绸百褶裙
# finished: 大红皮球花绸栏杆裙
# finished: 梅兰竹菊纹绉绸女棉袄
# finished: 腰饰带
# finished: 缎地彩绣荷花小脚鞋
# finished: 蓝绸团窠蔓草纹罗褂
# finished: 蔓草四叶纹绸女褂
# finished: 梅兰竹菊纹绉绸女褂
# finished: 绸地梅竹菊纹女衣
# finished: 缠枝蝙蝠荷花纹女衫
# finished: 小花绸地彩绣荷花裙
# finished: 玫红云鹤马面裙
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=18
# finished: 红绸彩绣折枝花卉栏杆裙
# finished: 红绸盘金绣梅竹马面裙
# finished: 红绸彩绣花蝶仙鹤马面裙
# finished: 黑缎彩绣团花牡丹女衣
# finished: 宝蓝缎彩绣玉堂富贵女衬衣
# finished: 黄绸地绣花小脚鞋
# finished: 黄缎风帽
# Error: https://www.chinasilkmuseum.com/zggd/info_21.aspx?itemid=1972, Reason: HTTPSConnectionPool(host='www.chinasilkmuseum.com', port=443): Max retries exceeded with url: /zggd/info_21.aspx?itemid=1972 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000023EE1A03250>, 'Connection to www.chinasilkmuseum.com timed out. (connect timeout=10)'))
# finished: 白缎栏杆裙
# finished: 黄色素绫衫
# finished: 黄色缠枝莲菊绫衫
# finished: 黄色曲水小花绸衫
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=19
# finished: 黄色花卉绸斜襟衫
# finished: 大红云蝠杂宝纹绸地彩绣团花童衣
# finished: 大窠杂宝团花广袖女衫
# finished: 蓝色暗花缎琵琶襟马甲
# finished: 织锦龙凤马面裙
# finished: 白缎绣龙凤女裙
# finished: 黑缎三蓝绣花卉小脚鞋
# finished: 黄色绉绸彩绣花蝶围巾
# finished: 蓝色绉绸彩绣花蝶围巾
# finished: 石青广袖绢女褂
# finished: 洋红缎女裤
# finished: 粉红色芙蓉暗花缎女裤
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=20
# finished: 蓝绢袄
# finished: 白缎彩绣花草裙带
# finished: 月白云幅暗花绸绣福寿花卉裙带
# finished: 大红柿蒂小花绸童褂
# finished: 黑缎团花马褂
# finished: 横罗盘金打籽绣鹿鹤同春饰带
# finished: 凤尾裙带
# finished: 彩绣花卉纹百褶鱼鳞裙
# finished: 彩绣花蝶凤尾裙
# finished: 月华裙
# finished: 红色皮球花纹绸马面裙
# finished: 三蓝绣太平富贵纹栏杆裙
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=21
# finished: 清红地平绣团花对襟女褂
# finished: 晚清黑缎地彩绣花卉动物纹绣鞋
# finished: 晚清黑地彩绣花卉纹尖头绣鞋
# finished: 晚清五彩贴绣花卉纹四瓣花形口围
# finished: 晚清五彩贴绣花卉纹四瓣花形口围
# finished: 五彩贴绣花卉纹方形口围
# finished: 晚清五彩贴绣花卉纹方形口围
# finished: 晚清紫地彩色贴绣口围
# finished: 晚清黑地彩绣花卉口围
# finished: 晚清红地彩绣花卉纹方形口围
# finished: 晚清红地彩绣蝶恋花纹方形口围
# finished: 白地打籽绣“福寿万代”挽袖
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=22
# finished: 清黄地流云蝙蝠纹妆花龙袍
# finished: 清绛地云蝠纹妆花龙袍
# Error: https://www.chinasilkmuseum.com/zggd/info_21.aspx?itemid=1931, Reason: HTTPSConnectionPool(host='www.chinasilkmuseum.com', port=443): Max retries exceeded with url: /zggd/info_21.aspx?itemid=1931 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000023EE1314210>, 'Connection to www.chinasilkmuseum.com timed out. (connect timeout=10)'))
# finished: 石青缎平金绣花蝶童帽
# finished: 蓝绉绸彩绣花蝶童褂
# finished: 蓝地云龙两色绸夹褂
# finished: 马面裙
# finished: 缂丝蓝地云蝠牡丹八宝九龙夹袍
# finished: 彩绣女褂
# finished: 紫色花卉纹暗花缎袄
# finished: 妆花缎蟒袍
# finished: 竹子花卉纹暗花绸裤
# The current result page being processed is: https://www.chinasilkmuseum.com/zggd/list_21.aspx?era=%u6E05%u4EE3&page=23
# finished: 漳绒马褂
# finished: 三蓝绣女褂
# finished: 盘金绣暗八仙云龙纹龙袍
# finished: 绿缎地彩绣仕女花蝶纹百褶裙
# finished: 红缎地彩绣肚兜
# finished: 黑绸地彩绣花蝶纹褂襴
# finished: 大红风景织锦裙
# finished: 暗花缎长袍
# finished: 缎地彩绣戏出十团褂
# finished: 紫色马面裙
# finished: 彩绣旗服
# finished: 明黄色盘金绣小龙袍
# 已经到达最后一页。
